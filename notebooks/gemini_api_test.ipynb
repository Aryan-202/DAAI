# %%
from google import genai
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
client = genai.Client(api_key=os.getenv('GEMINI_API_KEY'))

# %%
response = client.models.generate_content(
    model='gemini-2.5-flash', contents='Hello from the gemini api'
)

print(response.text)
# Out:
# Hello! It's good to hear from you. How can I help you today?
